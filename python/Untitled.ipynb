# %%
import pandas as pd

# %%
df=pd.read_csv("bank.csv")

# %%
df.head()
# Out:
#   Bank_Name                  Card_Name  Annual_Fee  \
# 0     ICICI  platinum ship credit card           0
# 1     ICICI      Amazon pay icici card           0
# 2     ICICI          Coral Credit Card         500
# 3      IDFC                  Millennia           0
# 4      IDFC              First Classic           0
#
#    Grocery_Cashback(%) [Zepto, BigBasket, etc.]  Travel_Cashback(%)  \
# 0                                           1.5                 2.0
# 1                                           3.0                 5.0
# 2                                           5.0                10.0
# 3                                           1.0                 0.0
# 4                                           0.0                 0.0
#
#    Dining_Cashback [Swiggy, Zomato, etc.](%) Min_Income_Required(Yearly)  \
# 0                                       15.0                      300000
# 1                                        3.0                      300000
# ...

# %%
df.describe()
# Out:
#          Annual_Fee  Grocery_Cashback(%) [Zepto, BigBasket, etc.]  \
# count     78.000000                                     78.000000
# mean     794.064103                                      1.621795
# std     1951.845163                                      2.339922
# min        0.000000                                      0.000000
# 25%        0.000000                                      0.000000
# 50%      325.000000                                      1.000000
# 75%      500.000000                                      2.000000
# max    12500.000000                                     10.000000
#
#        Travel_Cashback(%)  Dining_Cashback [Swiggy, Zomato, etc.](%)  \
# count           78.000000                                  78.000000
# mean             2.576923                                   3.121795
# std              3.767666                                   4.943306
# min              0.000000                                   0.000000
# ...

# %%
df.columns
# Out:
# Index(['Bank_Name', 'Card_Name', 'Annual_Fee',
#        'Grocery_Cashback(%) [Zepto, BigBasket, etc.]', 'Travel_Cashback(%)',
#        'Dining_Cashback [Swiggy, Zomato, etc.](%)',
#        'Min_Income_Required(Yearly)', 'Limit(montly)', 'Grocery Discount',
#        'Travel_Discount', 'Dining_Discount', 'Rewards Points',
#        'Review InPoints(out of 5)', 'CardType', 'Lounge access per year',
#        'Total Cashback(%)'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# Bank_Name                                                           ICICI
# Card_Name                                       platinum ship credit card
# Annual_Fee                                                              0
# Grocery_Cashback(%) [Zepto, BigBasket, etc.]                          1.5
# Travel_Cashback(%)                                                    2.0
# Dining_Cashback [Swiggy, Zomato, etc.](%)                            15.0
# Min_Income_Required(Yearly)                                        300000
# Limit(montly)                                                       60000
# Grocery Discount                                                        1
# Travel_Discount                                                         8
# Dining_Discount                                                        15
# Rewards Points                                                       0.02
# Review InPoints(out of 5)                                             4.5
# ...

# %%
df.sort_values("Grocery_Cashback(%) [Zepto, BigBasket, etc.]", ascending=False)
# Out:
#               Bank_Name                              Card_Name  Annual_Fee  \
# 27       Bank of Baroda                      IRCTC Credit Card         500
# 28       Bank of Baroda                      Prime Credit Card           0
# 26       Bank of Baroda                       HPCL Credit Card         499
# 44            Axis Bank            Axis Bank Value+ Debit Card           0
# 2                 ICICI                      Coral Credit Card         500
# ..                  ...                                    ...         ...
# 42            Axis Bank           Axis Bank MyZone Credit Card         500
# 43            Axis Bank           Axis Bank Delight Debit Card           0
# 45            Axis Bank  Axis Bank Titanium Rewards Debit Card           0
# 46            Axis Bank          Axis Bank Platinum Debit Card           0
# 77  Kotak Mahindra Bank            Kotak UPI RuPay Credit Card           0
#
# ...

# %%
df.sort_values("Dining_Cashback [Swiggy, Zomato, etc.](%)", ascending=False)
# Out:
#               Bank_Name                     Card_Name  Annual_Fee  \
# 43            Axis Bank  Axis Bank Delight Debit Card           0
# 2                 ICICI             Coral Credit Card         500
# 0                 ICICI     platinum ship credit card           0
# 15                IDBI       IDBI Delight Credit Card         500
# 16                IDBI          Royale Signature card        2500
# ..                  ...                           ...         ...
# 26       Bank of Baroda              HPCL Credit Card         499
# 27       Bank of Baroda             IRCTC Credit Card         500
# 28       Bank of Baroda             Prime Credit Card           0
# 42            Axis Bank  Axis Bank MyZone Credit Card         500
# 77  Kotak Mahindra Bank   Kotak UPI RuPay Credit Card           0
#
#     Grocery_Cashback(%) [Zepto, BigBasket, etc.]  Travel_Cashback(%)  \
# 43                                           0.0                 0.0
# ...
