# %% [markdown]
# #### CREATE A DIRCTORY
# #### PUT A FILE INSIDE A DIRECTORY
# #### WRITE A DATA INSIDE THE FILE
# #### READ A DATA INSIDE THE FILE
# #### DELETE A DIRECTORY

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Day 3.ipynb', 'Untitled1.ipynb']

# %%
os.mkdir('new')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Day 3.ipynb', 'new', 'Untitled1.ipynb']

# %%
os.chdir('./new')

# %%
os.listdir()
# Out:
# []

# %%
file=open('new.txt','w')

# %%
os.listdir()
# Out:
# ['new.txt']

# %%
file.write("welcome\nhi how are\nyou")
# Out:
# 22

# %%
file.close()

# %%
file=open('new.txt','r')

# %%
file.read()
# Out:
# 'welcome\nhi how are\nyou'

# %%
file.seek(0)
file.readlines()
# Out:
# ['welcome\n', 'hi how are\n', 'you']

# %%
file.close()

# %%
os.chdir('../')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Documents\\tran\\Data Enginnering\\Day 3'

# %%
#
os.rmdir('new')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 2
#       1 #
# ----> 2 os.rmdir('new')
#
# OSError: [WinError 145] The directory is not empty: 'new'

# %%
import shutil
shutil.rmtree('new')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Documents\\tran\\Data Enginnering\\Day 3'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Day 3.ipynb', 'Untitled1.ipynb']
