# %% [markdown]
# # FILE HANDLING

# %%
import os
file=open("C:/Users/Administrator/Desktop/new.txt")

# %%
import os
os.getenv("Home")

# %%
import os
os.getenv("C:/Users/Administrator/Desktop")
file=open("new.txt","w")
file.write("hi how are \n")
file.write("you \nwelcome")
# Out:
# 12

# %%
file=open("new.txt","r")
print(file.read())
# Out:
# hi how are
# you
# welcome

# %%
str="this is 1st module"
str[5:11]
# Out:
# 'is 1st'

# %%
file=open("new.txt","r")
file.read(3)
# Out:
# 'hi '

# %%
file.read(5)
# Out:
# 'how a'

# %%
file.seek(3)
# Out:
# 3

# %%
file.tell()
# Out:
# 3

# %%
file.read()
# Out:
# 'how are \nyou \nwelcome'

# %%
file.seek(0)
file.readline()
# Out:
# 'hi how are \n'

# %%
file.readlines()
# Out:
# ['you \n', 'welcome']

# %%
file.seek(0)
for l in file:
    print(l)
file.close()
# Out:
# hi how are
#
# you
#
# welcome

# %%
import os
os.rename('new.txt','old.txt')

# %%
file=open('old.txt','r')
file.read()
# Out:
# 'hi how are \nyou \nwelcome'

# %%
file.close()

# %%
os.remove('old.txt')

# %%
file=open('old.txt','r')
file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 file=open('old.txt','r')
#       2 file.read()
#
# File C:\Program Files\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'old.txt'

# %%
#get current working dirctory
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Documents\\tran\\Data Enginnering\\Day 3'

# %%
#change the directory
os.chdir("C:/Users/Administrator/Desktop")

# %%
#get current working directory
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
#lists the directory
os.listdir()
# Out:
# ['desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'Readme - Shortcut.lnk']

# %%
os.listdir('C:\\Users\\Administrator\\Documents\\tran\\Data Enginnering\\Day 3')
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %%
#create a new directory
os.mkdir('New')

# %%
os.listdir()
# Out:
# ['desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDBCompass.lnk',
#  'New',
#  'Readme - Shortcut.lnk']

# %%
os.chdir("C:\\Users\\Administrator\\Documents\\tran\\Data Enginnering\\Day 3")

# %%
os.mkdir('New')

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
os.rmdir('new')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
os.mkdir('new')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'new', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
f=open('new/new.txt','w')

# %%
f.close()

# %%
os.listdir('new')
# Out:
# ['new.txt']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Documents\\tran\\Data Enginnering\\Day 3'

# %%
os.rmdir('new')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 os.rmdir('new')
#
# OSError: [WinError 145] The directory is not empty: 'new'

# %%
import shutil
shutil.rmtree('new')

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from math import pi 
print(pi)
# Out:
# 3.141592653589793

# %%
from math import * #same as "import math"
print(math.pi)
# Out:
# 3.141592653589793

# %%
from math import pi as PI
print(PI)
# Out:
# 3.141592653589793

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-02-20 10:54:55.480388

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2026-02-20 10:57:34.220742

# %%
from datetime import datetime as dt
print(dt.now())
# Out:
# 2026-02-20 10:58:00.659844

# %%
def num(n):
   return n>10
def test_add():
    assert num(11)==False
try:
    test_add()
except AssertionError:
    print("Error")
# Out:
# Error
