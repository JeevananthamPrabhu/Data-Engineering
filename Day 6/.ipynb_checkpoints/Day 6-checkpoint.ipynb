# %%
# coding -5
# presentation -5
# communication -5
# teamwork-5

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.random.random_sample(5)
data
# Out:
# array([0.32531118, 0.3215078 , 0.7156821 , 0.53732618, 0.61763213])

# %%
plt.hist(data,color='red')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x=[1,2,3,7]
y=[3,7,8,10]
plt.scatter(x,y,color='g')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title('Scatter plot')
plt.show()

# %% [markdown]
# # Pie chart

# %%
cat=['Food','House Rent','Transportation','Entertainment']
ex=[2200,4100,3000,1000]

# %%
plt.pie(ex,labels=cat,autopct='%.2f%%')
plt.title("Monthly Expenses")
plt.legend()
plt.show()

# %%
plt.pie(ex,labels=cat,autopct='%.2f%%',startangle=90,explode=[0.2,0,0,0],shadow=True)
plt.title("Monthly Expenses")
plt.legend()
plt.show()

# %% [markdown]
# # Box plot

# %%
data=[12,3,45,1,-24,-2,4,43,120]
plt.boxplot(data)
plt.title("Box PLot")
plt.xlabel("Data")
plt.ylabel('Values')
plt.show()

# %% [markdown]
# # Stack plot

# %%
quaters=['Q1','Q2','Q3','Q4']
ele=[1000,12000,11000,9000]
clo=[5000,6000,9000,9050]
apl=[3000,4000,8250,9000]
plt.figure(figsize=(10,8))
plt.stackplot(quaters,ele,clo,apl,labels=['Electronics','Clothings','Appliances'])
plt.xlabel('Quaters')
plt.ylabel('Sales')
plt.title('Product Sales Over Quarter')
plt.legend()
plt.show()

# %% [markdown]
# # 3D Scatter plot

# %%
from mpl_toolkits.mplot3d import Axes3D
x=np.linspace(-5,5,100)
y=np.linspace(-5,5,100)
x,y=np.meshgrid(x,y)
z=np.sin(np.sqrt(x**2+y**2))
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(x,y,z,c=z,cmap='viridis')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.show()

# %% [markdown]
# # Subplot

# %%
x=np.linspace(0,10,100)
y1=np.sin(x)
y2=np.cos(x)
y3=np.tan(x)
y4=np.exp(-x)
fig,axs=plt.subplots(2,2,figsize=(10,8))
axs[0,0].plot(x,y1,'r')
axs[0,0].set_title('Sine Wave')
axs[0,1].plot(x,y2,'b')
axs[0,1].set_title('Cos Wave')
axs[1,0].plot(x,y3,'g')
axs[1,0].set_title('Tan Wave')
axs[1,1].plot(x,y4,'m')
axs[1,1].set_title('Exponential Decay')
plt.tight_layout()
plt.show()
