# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('C:/Users/Administrator/Downloads/Comprehensive_Banking_Database.csv')

dates=df["Date Of Account Opening"]

d=np.arange(2000,2023)
print(d)
l=[0]*23
for date in dates:
    year=int(date.split('/')[2])
    l[year%2000]+=1
print(l)

plt.figure(figsize=(10,5))
plt.plot(d,l,marker='o',ms=3,color='b')
plt.xlabel('Year')
plt.ylabel('No of Account')
plt.title("New Account openings")
plt.show()
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021 2022]
# [218, 217, 227, 225, 223, 216, 220, 214, 190, 198, 207, 219, 244, 219, 216, 220, 227, 228, 206, 206, 246, 212, 202]
